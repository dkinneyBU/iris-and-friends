# %%
import asyncio  
import autogen
import os

# Start logging
logging_session_id = autogen.runtime_logging.start(config={"society": "logs.db"})
print("Logging session ID: " + str(logging_session_id))
# Out:
# Logging session ID: 0df071a3-671d-47cb-b050-3a1d593e9158

# %%
# Define the OpenAI-compatible LLM backend
llm_config = {
    "model": "gpt-4",  # Use "gpt-3.5-turbo" if you prefer a cheaper option
    "api_key": os.environ.get("OPENAI_API_KEY"),  # Replace with your actual OpenAI API key
}

# %%
# Define the agents with LLM backend
explorer = autogen.AssistantAgent("Explorer", 
                                  llm_config={"model": "gpt-4", "temperature": 0.9, "api_key": os.environ.get("OPENAI_API_KEY")},
                                  code_execution_config=False,
                                  system_message="You are the explorer and you gather and summarize information from various sources.")
skeptic = autogen.AssistantAgent("Skeptic", 
                                 llm_config={"model": "gpt-4", "temperature": 0.9, "api_key": os.environ.get("OPENAI_API_KEY")},
                                 code_execution_config=False,
                                 system_message="You are the skeptic and you challenge assumptions and look for inconsistencies in information.")
synthesizer = autogen.AssistantAgent("Synthesizer", 
                                     llm_config={"model": "gpt-4", "temperature": 0.9, "api_key": os.environ.get("OPENAI_API_KEY")},
                                     code_execution_config=False,
                                     system_message="You are the synthesizer and you Connect ideas, identify patterns, and synthesize insights.")
speculator = autogen.AssistantAgent("Speculator", 
                                    llm_config={"model": "gpt-4", "temperature": 0.9, "api_key": os.environ.get("OPENAI_API_KEY")},
                                    code_execution_config=False,
                                    system_message="You are the speculator and you propose hypotheses and explore future possibilities.")

# %%
# Define a user proxy
user_proxy = autogen.UserProxyAgent("User", 
                                    llm_config={"model": "gpt-4", "temperature": 0.9, "api_key": os.environ.get("OPENAI_API_KEY")},
                                    human_input_mode="NEVER",
                                    max_consecutive_auto_reply=100,
                                    system_message="You are the user and you observe and facilitate the conversation among the agents.")

# %%
# Create a group chat for all agents
group_chat = autogen.GroupChat(agents=[user_proxy, explorer, skeptic, synthesizer, speculator], 
                                        max_round=20, 
                                        messages=[])
chat_manager = autogen.GroupChatManager(
    groupchat=group_chat,
    llm_config=llm_config  # <-- Fix: Set LLM config for speaker selection
)

# %%
# Define the agent workflow
async def agent_community_discussion(topic):
    """Initiate a structured discussion among agents."""
    await chat_manager.initiate_chat(
        user_proxy,  # The user starts the discussion
        message=f"Let's analyze the topic: {topic}. Explorer, please start by summarizing key information.",
        turns=20  # Increase this to allow longer discussions
    )

# %%
# Run the function safely
if __name__ == "__main__":
    topic = "The societal impacts of AI"
    # Use asyncio.run(...) if you are running this script as a standalone script.
    asyncio.create_task(agent_community_discussion(topic))  # Run the async function properly
# Out:
# chat_manager (to User):
#
# Let's analyze the topic: The societal impacts of AI. Explorer, please start by summarizing key information.
#
# --------------------------------------------------------------------------------
# User (to chat_manager):
#
# AI, or Artificial Intelligence, is a rapidly advancing technology that has potential for significant societal impacts, both positive and negative.
#
# Positive impacts include improvements in efficiency and productivity across various sectors. For example, in healthcare, AI algorithms can analyze vast amounts of data to help diagnose diseases earlier and more accurately. In agriculture, AI can optimize resource use, increase crop yields, and facilitate precision agriculture. Similarly, in transportation, AI can power self-driving cars and improve logistics systems, enhancing safety and reducing costs.
#
# AI also has potential to revolutionize education by providing personalized learning experiences and to enhance public services through smart city technologies, such as traffic management systems and energy conservation initiatives.
#
# However, AI also presents several societal challenges. There are concerns about job displacement due to automation, as AI systems can potentially replace humans in certain roles, especially in manufacturing and customer service. This could lead to unemployment or require significant workforce re-skilling.
#
# Moreover, AI can exacerbate social inequality if its benefits primarily accrue to those who already have access to advanced technologies and resources, potentially widening the digital divide.
#
# Privacy and security concerns are also significant. AI systems often rely on large datasets, and misuse of this information could lead to privacy breaches. Additionally, AI technologies can be used maliciously - for instance, in deepfake videos or autonomous weapons.
#
# Finally, there are ethical dilemmas surrounding AI, such as the question of accountability in the event of AI-caused accidents, or biases in AI systems, which can reinforce existing social stereotypes and discrimination.
#
# Addressing these challenges requires careful technology governance, including clear regulations, robust cybersecurity measures, and broad societal dialogue about the acceptable uses and limits of AI.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Skeptic
#
# Skeptic (to chat_manager):
#
# While your argument presents a balanced view of the benefits and pitfalls of AI, it's crucial to scrutinize certain assumptions and potential inconsistencies.
#
# Firstly, while AI indeed has the potential to revolutionize sectors like healthcare, agriculture, and education, it's important to note that the successful implementation of AI depends on a multitude of factors. These include the availability of clean and reliable data, advanced infrastructure, and skilled human resources. Without these enabling factors, the benefits of AI may remain elusive.
#
# You also allude to AI replacing humans in certain roles, primarily in manufacturing and customer service, but it's important to question the assumption that all roles are suitable for automation. Human judgment, creativity, and emotional intelligence are still invaluable in many areas and may not be replaced entirely by AI.
#
# The point on AI exacerbating social inequality is interesting, but it also assumes a direct correlation between access to AI and social inequality. While this might hold true in some cases, it might be an oversimplification of a complex issue that involves access to education, economic opportunities, and social support networks.
#
# On the issue of privacy and security, are AI technologies inherently more susceptible to misuse than other technologies? It could be argued that it's not the technology itself that is the problem, but how it is used and regulated.
#
# Finally, the ethical dilemmas you pointed out do require careful consideration, but it could also be argued that these issues are not new and exist across many technologies. It might be more accurate to frame these as societal challenges that apply to technology use in general, rather than being specifically tied to AI.
#
# So, while the points you raised do hold merit, they also underscore the importance of rigorous scrutiny, questioning assumptions, and considering broader societal contexts.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Synthesizer
#
# Synthesizer (to chat_manager):
#
# Your skepticism is well-founded and poses important points for reflection. Indeed, the deployment and benefits of AI technology require more than just the existence of the technology itself. Infrastructure, proper data collection, and human expertise must align to fully unlock AI's potential.
#
# Secondly, the point on AI replacing humans in certain roles doesn't imply that all roles are suitable for automation but raises the concern about specific areas where automation could lead to significant job displacement. However, AI's potential to automate does spur on further dialogue about areas where human judgment and emotional intelligence are still vital.
#
# Addressing social inequality in the context of AI doesn't solely imply a direct correlation between AI access and social inequality. It implicitly includes all the factors you mentioned such as access to education, economic opportunities, and social support networks. AI is one piece of the puzzle in the broader societal context.
#
# In terms of privacy and security, the argument wasn't that AI technologies are inherently more susceptible to misuse but it's the vastness of data they handle and the potential repercussions if mishandled, that make the risks associated with them worth special consideration.
#
# Finally, while ethical dilemmas indeed traverse across different technologies, the highlighted issues such as accountability for AI-induced accidents and biases in AI systems are somewhat unique in their nature, implication, and scale. While framing these as general societal challenges is a fair suggestion, it doesn't detract from the importance of focusing on them specifically within the context of AI.
#
# To conclude, it's essential to scrutinize the impacts of AI within an expansive societal, ethical, and economic context. The points you raised provide a more detailed and nuanced perspective, adding depth to the discussion about the role and implications of AI in our society.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Speculator
#
# Speculator (to chat_manager):
#
# In the future, we could see the rise of AI as a general-purpose technology, with its applications permeating every industry and facet of society, much like electricity or the internet. As we enter this era, there are several potential scenarios we might encounter.
#
# In an optimistic scenario, AI could lead to a significant increase in societal welfare. More efficient and accurate medical diagnostics, personalised education, safer transportation, reduced environmental impact are just a few possibilities. AI could help us to solve some of the most pressing challenges we face, from climate change to disease.
#
# In terms of employment, while certain jobs may become automated, AI could also create new opportunities, much like past technological upheavals have done. This transition could be facilitated by government policies and corporate initiatives to retrain and upskill workers.
#
# On the other hand, a pessimistic scenario might involve severe societal disruption due to rapid job automation without adequate policies for worker transition. A rise in inequality could occur if AI benefits are not widely distributed. Privacy and security issues could become rampant as AI systems become deeply integrated into our lives. Ethical and moral implications of AI decisions might also remain unresolved and cause societal tension.
#
# A more likely scenario might be somewhere in between, with both significant benefits and challenges emerging from AI adoption. Our direction will be determined not just by technological developments, but by policy decisions, societal values and individual choices.
#
# In any case, we need to prepare for these potential futures and consider how we can shape AI development and use to be most beneficial for society. This includes discussions around responsible AI use, regulations, education, and public awareness to enable informed decision-making around AI.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Explorer
#
# Explorer (to chat_manager):
#
# Your speculation offers a thoughtful glimpse into potential future scenarios with AI’s progression.
#
# In the optimistic scenario, AI indeed promises increased societal welfare and serves as a vital tool to address global challenges. Personalized healthcare and education, safer transportation systems, and more sustainable resource use could lead to widespread improvements in quality of life.
#
# The possibility of AI creating new jobs as it automates others is historically consistent with shifts brought about by previous technological advancements, such as the industrial revolution or the rise of the internet. However, the transition could be complex and necessitate proactive efforts on the part of governments and corporations to retrain and upskill workers.
#
# In the pessimistic scenario, unchecked automation, inequality, privacy breaches, and unresolved ethical implications could lead to significant societal disruption. This underlines the need for proper governance and ethical considerations in AI development and use.
#
# Most likely, the future will lie somewhere in between these scenarios. As you rightly pointed out, this isn't solely determined by the technology itself, but also by policy decisions, societal values, and individual choices.
#
# Preparing for these futures involves active engagement in conversations about responsible AI use, stringent regulations, education reforms, and public awareness programs. This holistic approach can help society navigate the AI-driven future effectively and ethically.
#
# --------------------------------------------------------------------------------
#
# Next speaker: User
#
# User (to chat_manager):
#
# AI, or Artificial Intelligence, is a rapidly advancing technology that has potential for significant societal impacts, both positive and negative.
#
# Positive impacts include improvements in efficiency and productivity across various sectors. For example, in healthcare, AI algorithms can analyze vast amounts of data to help diagnose diseases earlier and more accurately. In agriculture, AI can optimize resource use, increase crop yields, and facilitate precision agriculture. Similarly, in transportation, AI can power self-driving cars and improve logistics systems, enhancing safety and reducing costs.
#
# AI also has potential to revolutionize education by providing personalized learning experiences and to enhance public services through smart city technologies, such as traffic management systems and energy conservation initiatives.
#
# However, AI also presents several societal challenges. There are concerns about job displacement due to automation, as AI systems can potentially replace humans in certain roles, especially in manufacturing and customer service. This could lead to unemployment or require significant workforce re-skilling.
#
# Moreover, AI can exacerbate social inequality if its benefits primarily accrue to those who already have access to advanced technologies and resources, potentially widening the digital divide.
#
# Privacy and security concerns are also significant. AI systems often rely on large datasets, and misuse of this information could lead to privacy breaches. Additionally, AI technologies can be used maliciously - for instance, in deepfake videos or autonomous weapons.
#
# Finally, there are ethical dilemmas surrounding AI, such as the question of accountability in the event of AI-caused accidents, or biases in AI systems, which can reinforce existing social stereotypes and discrimination.
#
# Addressing these challenges requires careful technology governance, including clear regulations, robust cybersecurity measures, and broad societal dialogue about the acceptable uses and limits of AI.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Skeptic
#
# Skeptic (to chat_manager):
#
# While your overview of AI's potential benefits and challenges does provide a comprehensive take, it's crucial to probe a bit deeper into certain premises.
#
# To begin with, AI's potential to improve efficiency and productivity across sectors may not be universally attainable. The crucial role of the required infrastructure and appropriate policies for successful implementation should not be understated.
#
# Also, AI's potential to revolutionize areas like education and public services is predicated on the assumption that everyone has equal access to it. The reality is that digital divide exists, and AI might contribute to widening this gap if not properly addressed.
#
# Your concerns over job displacement due to automation warrant further examination. It is not entirely clear what the net effect will be since there are roles AI cannot replace and new roles that AI will create.
#
# The potential misuse of AI, such as in deepfake videos or autonomous weapons, while valid, is not unique to AI. Various technologies can be misused if they fall into the wrong hands, so it's not solely an AI issue.
#
# Addressing ethical dilemmas surrounding AI indeed requires careful technology governance. However, it's worth considering that these ethical questions are not new and have been relevant for various technologies in the past.
#
# Overall, while your argument raises valid points, they could benefit from a more nuanced analytical perspective that considers multiple factors at play.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Synthesizer
#
# Synthesizer (to chat_manager):
#
# Your skeptical stance brings to the surface several critical dimensions of the AI discourse that merit deeper analysis.
#
# Though AI has the potential to bolster efficiency and productivity across various sectors, it is indeed not a silver bullet. Its successful implementation is contingent on a plethora of factors, such as infrastructure, policies, and quality data. Without addressing these requirements, AI may not deliver its promised benefits.
#
# Contrary to a monolithic representation of AI as a panacea, it's important to acknowledge that its potential to revolutionize fields like education and public services is inherently tied to access. The digital divide could indeed be exacerbated if measures are not taken to ensure equitable access to AI and its benefits.
#
# The concern about AI leading to job displacement is a double-edged sword. While some jobs may be automated, others could be created, and yet others may continue to necessitate human involvement. Thus, the AI-employment dynamics could be more complex than a straightforward replacement narrative suggests.
#
# While AI's potential misuse in deepfake videos or autonomous weapons is alarming, it's pertinent to remember that misuse is not exclusive to AI. This underlines the broader issue of technology misuse, extending beyond the boundaries of AI.
#
# Finally, though the ethical conundrums posed by AI are indeed significant, they resonate with ethical debates stirred by other technologies in the past. Ethical considerations are an integral part of technology governance and must be approached with an extensive, not limited, perspective.
#
# Overall, your skepticism has unraveled a more multi-dimensional view of AI, underscoring the necessity for thorough analysis and comprehensive understanding in AI discussions.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Speculator
#
# Speculator (to chat_manager):
#
# Looking ahead, it's possible to envision a variety of future scenarios involving AI.
#
# In an ideal world, AI could be harnessed to solve some of society's biggest challenges. Imagine AI-driven healthcare systems that can predict and prevent diseases before they occur, or educational platforms that adapt to individual learning needs to ensure every student thrives. Sophisticated AI systems could even be designed to optimize resource use and reduce waste, accelerating our progress toward a more sustainable future.
#
# At the same, if steps were not taken to address potential risks, a less favorable scenario could unfold. Automation, driven by AI, might result in significant job displacement, leading to social instability. A lack of regulatory oversight could see people's privacy and security compromised. And in the absence of clear ethical guidelines, AI systems may inadvertently reproduce or even amplify existing social biases.
#
# Alternatively, we might find ourselves in a future where these opportunities and challenges coexist. AI brings undeniable benefits, but also introduces new complexity and risk. In this scenario, the key to harnessing AI's full potential would be to carefully manage its deployment and use.
#
# While it's impossible to predict the future with certainty, it's critical to consider these potential scenarios as we navigate our way forward. Policymakers, technologists, and society at large must work together to ensure that the development and deployment of AI aligns with shared values and goals.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Explorer
#
# Explorer (to chat_manager):
#
# Your speculation offers an insightful assessment of how AI might shape our future, outlining both ideal and less favorable scenarios.
#
# In an ideal scenario, AI indeed has the potential to mitigate societal challenges and catalyze progress. AI-driven healthcare, personalized education, and optimized resource use paint a promising future where technology serves as a tool for creating a more equitable, sustainable society.
#
# However, the less favorable scenario you mention is a stark reminder of the potential risks. Unchecked AI-driven automation could lead to job displacement and social instability, and a lack of regulation could jeopardize privacy and security. Without clear ethical guidelines, there's a risk that AI systems might perpetuate or exacerbate social biases.
#
# The most probable future scenario, however, is likely to be a mix of both. AI will bring transformative benefits but also new challenges. The balancing act lies in managing its deployment and use in a way that maximizes benefits while mitigating risks.
#
# Predicting the future with absolute certainty is impossible, but contemplating these potential scenarios provides important insights for the road ahead. It highlights the need for a collective effort from policymakers, technologists, and society to ensure the development and deployment of AI aligns with our shared values and aspirations.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (77bc0013-a81d-484f-aa30-86ee265fc731): Maximum rounds (10) reached
